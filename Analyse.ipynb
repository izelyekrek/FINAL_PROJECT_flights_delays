# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # to get the password without showing the input
password = getpass.getpass()
pd.options.display.max_columns = None
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/passenger_satisfaction'
engine = create_engine(connection_string)

data = pd.read_sql_query('SELECT * FROM data', engine)
data.head()
# Out:
#        id  gender      customer_type  age   type_of_travel     class  \
# 0    5047    Male  disloyal Customer   25  Business travel  Business
# 1  110028  Female     Loyal Customer   26  Business travel  Business
# 2   24026  Female     Loyal Customer   25  Business travel  Business
# 3  119299    Male     Loyal Customer   61  Business travel  Business
# 4  111157  Female     Loyal Customer   26  Personal Travel       Eco
#
#    flight_distance  inflight_wifi_service  departure/arrival_time_convenient  \
# 0              235                      3                                  2
# 1             1142                      2                                  2
# 2              562                      2                                  5
# 3              214                      3                                  3
# 4             1180                      3                                  4
#
#    ease_of_online_booking  gate_location  food_and_drink  online_boarding  \
# ...

# %%
query = '''
        SELECT satisfaction, gender, count(id)
        FROM data
        group by satisfaction, gender
        '''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#               satisfaction  gender  count(id)
# 0  neutral or dissatisfied    Male      20024
# 1                satisfied  Female      16960
# 2  neutral or dissatisfied  Female      21137
# 3                satisfied    Male      16998

# %%
query = '''
        SELECT gender, type_of_travel, avg(flight_distance)
        FROM data
        group by gender, type_of_travel
        '''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    gender   type_of_travel  avg(flight_distance)
# 0    Male  Business travel             1309.1773
# 1  Female  Business travel             1276.7683
# 2  Female  Personal Travel              785.9432
# 3    Male  Personal Travel              782.4442

# %%
query = '''
        SELECT gender, customer_type, class, count(id)
        FROM data
        where customer_type = 'Loyal Customer'
        and class = 'Eco'
        group by gender
        '''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    gender   customer_type class  count(id)
# 0  Female  Loyal Customer   Eco      13190
# 1    Male  Loyal Customer   Eco      13253

# %%
query = '''
        SELECT *, avg(Total_Score) 
        FROM ( 
        SELECT class, (inflight_wifi_service+"departure/arrival_time_convenient"+ease_of_online_booking+gate_location+food_and_drink+online_boarding+seat_comfort+inflight_entertainment+"on-board_service"+leg_room_service+baggage_handling+checkin_service+inflight_service+cleanliness)as Total_Score
        FROM data)
        '''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ...

# %%
query = '''
        SELECT gender, class, (inflight_wifi_service+"departure/arrival_time_convenient"+ease_of_online_booking+gate_location+food_and_drink+online_boarding+seat_comfort+inflight_entertainment+"on-board_service"+leg_room_service+baggage_handling+checkin_service+inflight_service+cleanliness)as Total_Score
        FROM data
        '''

data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    gender     class  Total_Score
# 0    Male  Business         29.0
# 1  Female  Business         46.0
# 2  Female  Business         35.0
# 3    Male  Business         43.0
# 4  Female       Eco         28.0
